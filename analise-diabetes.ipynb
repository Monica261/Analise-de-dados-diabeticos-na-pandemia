# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
dados = pd.read_excel('dados_diabete.xlsx')
# Out:
#                                           At a glance       2010       2019  \
# 0                        Diabetes estimates (20-79 y)        NaN        NaN
# 1                     People with diabetes, in 1,000s    7,632.5   16,780.8
# 2   Age-adjusted comparative prevalence of diabete...        6.4       10.4
# 3         People with undiagnosed diabetes, in 1,000s          -    7,719.2
# 4   Proportion of people with undiagnosed diabetes, %          -       46.0
# 5   Impaired glucose tolerance (IGT) estimates (20...        NaN        NaN
# 6                          People with IGT, in 1,000s    9,000.1   15,129.4
# 7       Age-adjusted comparative prevalence of IGT, %        7.3        9.5
# 8        Mortality attributable to diabetes (20-79 y)        NaN        NaN
# 9                     Deaths attributable to diabetes   83,109.0  135,196.7
# 10  Proportion of diabetes-related deaths in peopl...          -       40.3
# 11  Type 1 diabetes estimates in children and adol...        NaN        NaN
# 12   New cases of type 1 diabetes (0-14 y), in 1,000s        4.1        7.3
# 13   New cases of type 1 diabetes (0-19 y), in 1,000s          -        9.1
# 14                Type 1 diabetes (0-14 y), in 1,000s       26.0       51.5
# 15                Type 1 diabetes (0-19 y), in 1,000s          -       95.8
# 16        Hyperglycaemia in pregnancy (HIP) (20-49 y)        NaN        NaN
# 17                        Live births affected by HIP          -  282,165.4
# 18  Prevalence of gestational diabetes mellitus (G...          -       10.3
# 19  Live births affected by other types of diabete...          -   36,169.5
# 20  Live births affected by other types of diabete...          -   42,459.8
# 21                Diabetes-related health expenditure        NaN        NaN
# 22  Total diabetes-related health expenditure, USD...    4,296.7   52,300.2
# 23  Total diabetes-related health expenditure, ID ...    8,744.0   91,473.8
# 24  Mean diabetes-related health expenditure per p...      563.0    3,116.7
# 25  Mean diabetes-related health expenditure per p...    1,145.6    5,451.1
# 26                                       Demographics        NaN        NaN
# 27        Total adult population (20-79 y), in 1,000s  126,326.0  147,183.2
# 28         Population of children (0-14 y), in 1,000s   53,264.0   44,615.4
# 29  Population of children and adolescents (0-19 y...          -   61,194.1
#
#          2030       2045
# 0         NaN        NaN
# 1    21,493.6   25,968.6
# 2        11.9       12.7
# 3           -          -
# 4           -          -
# 5         NaN        NaN
# 6    18,085.4   20,521.8
# 7        10.1       10.4
# 8         NaN        NaN
# 9           -          -
# 10          -          -
# 11        NaN        NaN
# 12          -          -
# 13          -          -
# 14          -          -
# 15          -          -
# 16        NaN        NaN
# 17          -          -
# 18          -          -
# 19          -          -
# 20          -          -
# 21        NaN        NaN
# 22   60,336.8   63,610.9
# 23  105,530.0  111,256.0
# 24          -          -
# 25          -          -
# 26        NaN        NaN
# 27  163,416.7  171,058.3
# 28          -          -
# 29          -          -

# %%
plt.rcParams['figure.figsize'] = (10.7,6.8)
plt.rcParams['figure.facecolor'] = 'white'
plt.style.use("ggplot")

years = ['2010','2019','2030','2045']
quant = [7632.5, 16780.8, 21493.6, 25968.6]

plt.plot(years, quant,'ro')
plt.plot(years, quant,'k--', color = "blue")
plt.xlabel('Anos', fontsize = 17)
plt.ylabel('Quantidade', fontsize = 17)

plt.xticks(fontsize = 16, color = 'black')
plt.yticks(fontsize = 16, color = 'black')

plt.title('Quantidade de pessoas com diabetes desde 2010 e estimativa para 2030 e 2045', color = 'blue', fontsize = 19)

#plt.style.use("ggplot")
#fig = plt.figure()
#ax = fig.add_axes([0,0,0.8,1.2])
#years = ['2010','2019','2030','2045']
#quant = [7632.5, 16780.8, 21493.6, 25968.6]
#ax.bar(years, quant)
#plt.xlabel('Anos', fontsize = 13)
#plt.ylabel('Quantidade de pessoas', fontsize = 13)

#plt.xticks(fontsize = 13, color = 'black')
#plt.yticks(fontsize = 13, color = 'black')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Quantidade de pessoas com diabetes desde 2010 e estimativa para 2030 e 2045')

# %%
plt.style.use("ggplot")

fig = plt.figure(figsize=(4,4))
ax = fig.add_axes([0,0,0.8,1.2])
yearsDeath = ['2010', '2019']
quantDeath = [83109, 135196.7]

ax.bar(yearsDeath, quantDeath)
plt.xlabel('Anos', fontsize = 13)
plt.ylabel('Quantidade de pessoas', fontsize = 13)
plt.xticks(fontsize = 13, color = 'black')
plt.yticks(fontsize = 13, color = 'black')
plt.title('Quantidade de mortes por diabetes nos anos 2010 e 2019', color = 'blue', fontsize = 19)

plt.show()

# %%
print('Nascidos vivos em 2019 afetados por'+
      ' hiperglicemia na gravidez: 282.165,4')
# Out:
# Nascidos vivos em 2019 afetados por hiperglicemia na gravidez: 282.165,4

# %%
plt.rcParams['figure.figsize'] = (10.7,6.8)
yearsExp = ['2010', '2019', '2030', '2045']
expByMilion = [4296.7, 52300.2, 60336.8, 63610.9]
expByPerson = []

plt.plot(yearsExp, expByMilion, 'ro', color='green')
plt.plot(yearsExp, expByMilion, color='blue')

plt.xlabel('Anos', fontsize = 17)
plt.ylabel('US$', fontsize = 17)

plt.xticks(fontsize = 16, color = 'black')
plt.yticks(fontsize = 16, color = 'black')

plt.title('Despesa total em saúde relacionada à diabetes, em milhões de dólares', color = 'black', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'Despesa total em saúde relacionada à diabetes, em milhões de dólares')
